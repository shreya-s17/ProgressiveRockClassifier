# %%
# %matplotlib notebook
import numpy as np
import librosa
import matplotlib.pyplot as plt
import os
import sys
sys.path.append("/home/wgar/PRockClassify/")
from data.TestDatasetManifest import TestDatasetManifest

# %%
opt = {
    'root_test_prog': "/media/wgar/New Volume1/dataset/cap6610sp19_project/Validation Set/Prog",
    'root_test_nonprog': "/media/wgar/New Volume1/dataset/cap6610sp19_project/Validation Set/Non-Prog",
}
opt["sample_rate"] = 44100
opt["save_dir"] = None

# %%
test_manifest = TestDatasetManifest(opt, quiet=False)
# Out:
#   DEBUG    | TestDatasetManifest | number of test songs:	91

# %%
num_subset = 2
windows_per_minute = 4

# %%
fig, axes = plt.subplots(num_subset, 1)
fig.set_size_inches(8, 9)

minute = opt["sample_rate"] * 60.
samples_per_window = int(np.floor(minute / windows_per_minute))

for i, (full_path, target) in enumerate(np.random.permutation(test_manifest.manifest)[:num_subset]):
    print("Start song:\t{}".format(full_path))
    x, _ = librosa.load(full_path, sr=opt["sample_rate"], mono=True)
        
    real_x = np.zeros(num_minutes * minute)
    real_x[:len(x)] = x 
    stepping = len(real_x) / (opt["sample_rate"])
    idxes = np.random.permutation(range(len(real_x)))[:500 * num_minutes]
    idxes = sorted(idxes)

    for j, x_j in enumerate(np.arange(0, len(real_x), samples_per_window)):
        end = min(x_j + samples_per_window, len(idxes))
        axes[i].axvspan(end - x_j, end, color='red', alpha=(j % 10) / 10.)
        
    axes[i].plot(idxes, real_x[idxes])
    axes[i].set_ylim((-1.0, 1.0))
    del real_x
    del x
#     axes[i].set_xlim((0, len(real_x)))
# Out:
# <img src="data:image/png;base64,..." width="800">
# Start song:	/media/wgar/New Volume1/dataset/cap6610sp19_project/Validation Set/Non-Prog/102-weezer-getchoo.mp3
# Start song:	/media/wgar/New Volume1/dataset/cap6610sp19_project/Validation Set/Non-Prog/Sonic Youth - Daydream Nation - 01 - Teen Age Riot.mp3

# %%
np.zeros(4 * minute).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d6d4850b8493> in <module>()
# ----> 1 np.zeros(4 * minute).shape
#
# NameError: name 'np' is not defined

# %%
np.linspace(0, 100, 20)
# Out:
# array([  0.        ,   5.26315789,  10.52631579,  15.78947368,
#         21.05263158,  26.31578947,  31.57894737,  36.84210526,
#         42.10526316,  47.36842105,  52.63157895,  57.89473684,
#         63.15789474,  68.42105263,  73.68421053,  78.94736842,
#         84.21052632,  89.47368421,  94.73684211, 100.        ])
